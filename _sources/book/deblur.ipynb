# %% [markdown]
# # Image deblur (or Image Deconvolution)
#
# We consider the following computational imaging task:
#
# *Given a blurred and noisy image, reconstruct an image as close as possible to the one representing the object (also called in the following "exact image" or "ground truth")*
#
# The blurred image can be obtained by:
# - a lens (when the image is defocused) with imperfections
# - the relative movement bewteen the object and the imaging system (when the blur has a specific direction).
#
# In all the cases, the blurred image is obtained from a convolution of the exact image with a blurring kernel, called Point  Spread Function (PSF).
#
# ```{figure} immagini_sorgente/deconv1.png
# ---
# width: 90%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv1.png"  width="700">
#   <p align="center">
# </p>
#
#
# ```{figure} immagini_sorgente/deconv12.png
# ---
# width: 90%
# align: center
# ---
# ```
# <p align="center">
#   <img src="immagini_sorgente\deconv12.png"  width="800">
#   <p align="center">
# </p>
#
#
# Hence the aim in this case is, given a noisy convolution, supposed to know the convolution kernel, *deconvolve* the observed image to get the ground truth. This is a typical liner inverse problem that can be modelled as:
#
# $$y^{\delta}=K*x+e$$
#
# The LSIS is described as a convolution. really, it is possible to write the convolution also as a matriux-vector product.
#
# *Equivalence of convolution and matrix-vector product*
#
# The convolution $K*x=b$ can equivalently be written as a matrix-vector product $Ax=b$ where the matrix A has the follwoing form (suppose to use periodic boundary conditions and a 3x3 kernel $p_{i,j},i,j=1, \ldots 3$):
#
# ```{figure} immagini_sorgente/deconv24.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv24.png"  width="700">
#   <p align="center">
# </p>
#
# This matrix has a *cyclic block structure*, in particular a Block Cyclic with Cyclic Blocks (BCCB) structure.
#
# A BCCB matrix has a particular eigenvalue decomposition:
#
# $$A=F^T\Lambda F$$
# where the eigenvectior matrix $F$ is the Discrete Fourier Transform matrix.
#
# Hence, to compute the matrix-vector product $b=Ax$ we can compute:
# $$b=F^T\Lambda F x$$
#
# by means of FFT2 ($Fx$) and IFFT2 ($F^tx$) functions.
#
# **Space invariant blur**
#
# We can visually describe the imaging process as:
#
# ```{figure} immagini_sorgente/deconv2.png
# ---
# width: 90%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv2.png"  width="700">
#   <p align="center">
# </p>
#
#
# that can be detailed as:
#
# ```{figure} immagini_sorgente/deconv4.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv4.png"  width="700">
#   <p align="center">
# </p>
#
# In optical system the PSF represents the deformation on each pixel due to lens imperfection.
#
# We will consider in this course *Space Invariant PSF*. This means that the same PSF (convolution kernel) is applied to every pixel of the exact image.
# The final degraded image is the sum of the images obtained by applying the PSF to each pixel.
#
# ```{figure} immagini_sorgente/deconv3.png
# ---
# width: 100%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv3.png"  width="800">
#   <p align="center">
# </p>
#
#
#
#
# In this case we say that the PSF is space invariant and the mathematical model is a convolution.

# %% [markdown]
# Here you have some examples of PSFs represented as surfaces and as grayscale images:
#
# ```{figure} immagini_sorgente/deconv5.png
# ---
# width: 70%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv5.png"  width="700">
#   <p align="center">
# </p>
#
# ```{figure} immagini_sorgente/deconv6.png
# ---
# width: 70%
# align: center
# ---
# ```
#
#
# <p align="center">
#   <img src="immagini_sorgente\deconv6.png"  width="700">
#   <p align="center">
# </p>

# %% [markdown]
# Examples of blurred images:
#
# a) gaussian blur
#
# ```{figure} immagini_sorgente/deconv7.png
# ---
# width: 90%
# align: center
# ---
# ```
# <p align="center">
#   <img src="immagini_sorgente\deconv7.png"  width="700">
#   <p align="center">
# </p>
#
# The  PSF kernel is given by the following discretiazion of a gaussian function:
#
# ```{figure} immagini_sorgente/deconv8.png
# ---
# width: 30%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv8.png"  width="200">
#   <p align="center">
# </p>
#
# ```{figure} immagini_sorgente/deconv9.png
# ---
# width: 30%
# align: center
# ---
# ```
# <p align="center">
#   <img src="immagini_sorgente\deconv9.png"  width="300">
#   <p align="center">
# </p>
#
# b) motion blur
#
# ```{figure} immagini_sorgente/deconv10.png
# ---
# width: 30%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv10.png"  width="300">
#   <p align="center">
# </p>
#
# c) blur on color images
#
# ```{figure} immagini_sorgente/deconv11.png
# ---
# width: 90%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv11.png"  width="700">
#   <p align="center">
# </p>

# %% [markdown]
# **Deconvolution as an inverse problem**
#
# ```{figure} immagini_sorgente/deconv13.png
# ---
# width: 80%
# align: center
# ---
# ```
# <p align="center">
#   <img src="immagini_sorgente\deconv13.png"  width="500">
#   <p align="center">
# </p>
#
# So the question is: given a captured image  $g(x,y)$ and  a kernel $k(x,y)$ is it possible to recover $f(x,y)$?
#
# ```{figure} immagini_sorgente/deconv14.png
# ---
# width: 80%
# align: center
# ---
# ```
# <p align="center">
#   <img src="immagini_sorgente\deconv14.png"  width="500">
#   <p align="center">
# </p>
#
# This is the so called *non blind deconvolution* because we know $h$.

# %% [markdown]
# **How to restore $f$**
#
# We know that the naive solution of the inverse problem is obtained to invert the linear model
# $$K*x=y^{\delta} \ \ or \ \ Ax=y^{\delta}$$
#
# by means of the least squares:
#
# $$min_x ||K*x-y^{\delta}||_2^2$$
#
# How to solve this problem? In deblur, the most efficient computational way is to use the Discrete  Fourier Transform.
#
# Suppose that $f'(x,y)$ is the restored image. We call it $f'$ and not $f$ becuase it will never be perfectly reconstructed.
#
# (We call $h$ the PSF kernel in the following)
#
# We start from the case of no noise.
#
# ```{figure} immagini_sorgente/deconv15.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# $$f'(x,y)*h(x,y)=g(x,y)$$
# <p align="center">
#   <img src="immagini_sorgente\deconv15.png"  width="600">
#   <p align="center">
# </p>
#
# By means of the Convolution Theorem the relationship between the DFTs in the frequency space is:
#
# $$F'(u,v)H(u,v)=G(u,v)$$
#
# Hence to get $F'(u,v)$:
#
# $$F'(u,v)=\frac{G(u,v)}{H(u,v)}$$
#
# ```{figure} immagini_sorgente/deconv17.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv17.png"  width="600">
#   <p align="center">
# </p>
#
# then by applying the IDFT we get:

# %% [markdown]
# $$f'(x,y)=IDFT(F'(u,v))$$
#
# ```{figure} immagini_sorgente/deconv18.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv18.png"  width="600">
#   <p align="center">
# </p>
#
# *But there is a problem: NOISE*
#
# The real acquisition model is:
#
# ```{figure} immagini_sorgente/deconv19.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv19.png"  width="600">
#   <p align="center">
# </p>
#
# Hence the deconvolution process is represented as:
#
# ```{figure} immagini_sorgente/deconv20.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv20.png"  width="600">
#   <p align="center">
# </p>
#
# By applying the Fourier transform we obtain:

# %% [markdown]
# ```{figure} immagini_sorgente/deconv21.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv21.png"  width="600">
#   <p align="center">
# </p>
#
# where the high frequencies in $F'(u,v)$ are greatly amplified.
#
# Now if you invert, i.e you compute $f'(x,y)=IDFT(F'(u,v))$, you obtain this unreliable image dominated by noise:
#
# ```{figure} immagini_sorgente/deconv22.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv22.png"  width="600">
#   <p align="center">
# </p>
#
# AS we have already seen the niave solution is noisy and unacceptable.

# %% [markdown]
# *Why this happens?*
#
# ```{figure} immagini_sorgente/deconv23.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv23.png"  width="600">
#   <p align="center">
# </p>
#
# 1. where $H(u,v)=0$ $F'(u,v) = \infty$, hence $f'(x,y)$ is not recoverable.
#
# 2. the motion blur $H(u,v)$ is a low-pass filter itself.
#
# For high frequencies $(u,v)$, the noise in $G(u,v)$ is high.
#
# WE need some noise suppression, that is obtained by means of regularization.

# %% [markdown]
# Hence we apply model-based regularization approaches:
#
# $$min_{x} ||K*x-y^{\delta}||_2^2 + \lambda R(x)$$
#
# it is also possible to constraint the solution for example to be positive.
#
# $$min_{x \geq 0} ||K*x-y^{\delta}||_2^2 + \lambda R(x)$$

# %% [markdown]
# For example, if we consider Tikhonov regularization:
#
# $$min_x ||K*x-g||_2^2 + \lambda ||x||_2^2$$
#
# if we apply the Fourier transform we have as usual:
#
# $$F(u,v)H(u,v)=G(u,v)$$
#
# Hence the problem becomes to find $\hat F$ so that:
#
# $$\hat F =min |FH-G|^2+\lambda |F|^2$$
#
# and the close solution is:
#
# $$\hat F= \frac{H^*}{H^2+\lambda }G$$
#
# where $H^*$ is the conjugate of H.
#
# We remind that the conjugate of the complex number $a+ib$ is $a -ib$.

# %% [markdown]
# If we use different regularization functions, the solution of the minimization problem:
#
# $$min_x ||K*x -y^{\delta}||_2^2 + \lambda R(x)$$
#
# is obtained by means of the iterative optimization methods that we have seen in the last lesson.
#
# Remind that any time we need to perform the matrix-vector multiplication $Av$ or $A^Tw$ we do it in the Fourier space since this is a convolution in deblur.

# %% [markdown]
# **Blind deconvolution**
#
# We have considered, up to now, of knowing the PSF, i.e. the blurring kernel.
#
# ```{figure} immagini_sorgente/deconv25.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv25.png"  width="600">
#   <p align="center">
# </p>
#
# But in some real cases the PSF is not  known. In this case we call it   *blind deconvolution*.
#
# ```{figure} immagini_sorgente/deconv26.png
# ---
# width: 80%
# align: center
# ---
# ```
#
# <p align="center">
#   <img src="immagini_sorgente\deconv26.png"  width="600">
#   <p align="center">
# </p>
#
# We must recover both the kernel and the reconstructed image. The task is much more difficult and the model-based approach has not given satisfactory results. Today this task is approached by means of neural networks and the results are far better.
